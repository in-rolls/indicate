# %%
pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.15.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)

# %%
# %cd /content/drive/MyDrive/Colab/Transliterate/Main
# Out:
# /content/drive/MyDrive/Colab/Transliterate/Main

# %%
import json
import os
import time

import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa

from sklearn.model_selection import train_test_split

from encoder import Encoder
from decoder import Decoder

# %%
print(tf.__version__)
# Out:
# 2.7.0

# %% [markdown]
# # Load Dataset

# %%
input_target_df = pd.read_csv('./data/merged_hi_to_en.csv')

# %% [markdown]
# # Prepare Data for training

# %% [markdown]
# ## Append start and end of sequence for target

# %%
# append start and end of sequence for target
sos = '^'
eos = '$'

input_target_df['english'] = sos + input_target_df['english'].astype(str) + eos

# %%
input_target_df.head()
# Out:
#                      hindi                     english
# 0  प्रयात सुबोध चन्द्र दास   ^late subodh chandra das$
# 1    स्वर्गीय पिनाकि कुंडू         ^late pinaki kundu$
# 2   मृत नूर महम्मद बिश्वास  ^late nur mohammad biswas$
# 3         नारायण चंद्र डॉं      ^narayan chandra dawn$
# 4            आब्दुल मन्नान              ^abdul mannan$

# %% [markdown]
# ## Construct Vocab for Source and Target

# %%
input_words =  input_target_df['hindi'].tolist()
target_words =  input_target_df['english'].tolist()

# %%
print(f"Total number of input words {len(input_words)}")
print(f"Total number of target words {len(target_words)}")
# Out:
# Total number of input words 116021
# Total number of target words 116021

# %%
input_lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='', char_level=True)
input_lang_tokenizer.fit_on_texts(input_words)
input_tensor = input_lang_tokenizer.texts_to_sequences(input_words)
input_tensor = tf.keras.preprocessing.sequence.pad_sequences(input_tensor, padding='post')

# %%
target_lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='', char_level=True)
target_lang_tokenizer.fit_on_texts(target_words)
target_tensor = target_lang_tokenizer.texts_to_sequences(target_words)
target_tensor = tf.keras.preprocessing.sequence.pad_sequences(target_tensor, padding='post')

# %% [markdown]
# ## Save Vocab for Source and Target

# %%
# save tokenizers
hindi_tokenizer_json = input_lang_tokenizer.to_json()
with open('hindi_tokens.json', 'w') as f:
  json.dump(hindi_tokenizer_json, f)

english_tokenizer_json = target_lang_tokenizer.to_json()
with open('english_tokens.json', 'w') as f:
  json.dump(english_tokenizer_json, f)

# %% [markdown]
# ## Split data into Train and Validation

# %%
# split train and validation
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 120000

train_dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train))
train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

val_dataset = tf.data.Dataset.from_tensor_slices((input_tensor_val, target_tensor_val))
val_dataset = val_dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(train_dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 47]), TensorShape([64, 49]))

# %% [markdown]
# ## Summary of prepared dataset

# %%
vocab_inp_size = len(input_lang_tokenizer.word_index)+1
vocab_tar_size = len(target_lang_tokenizer.word_index)+1

max_length_input = input_tensor.shape[1]
max_length_output = target_tensor.shape[1]

embedding_dim = 256
units = 1024
steps_per_epoch = input_tensor.shape[0]//BATCH_SIZE

# %%
print('Number of samples:', len(input_words))

print('Input Vocab size:', vocab_inp_size)
print('Target Vocab size:', vocab_tar_size)

print('Max sequence length for inputs:', max_length_input)
print('Max sequence length for outputs:', max_length_output)
# Out:
# Number of samples: 116021
# Input Vocab size: 166
# Target Vocab size: 36
# Max sequence length for inputs: 47
# Max sequence length for outputs: 49

# %% [markdown]
# # Encoder

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# %% [markdown]
# ## Test Encoder

# %%
## Test Encoder Stack
# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_h, sample_c = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder h vecotr shape: (batch size, units) {}'.format(sample_h.shape))
print ('Encoder c vector shape: (batch size, units) {}'.format(sample_c.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 47, 1024)
# Encoder h vecotr shape: (batch size, units) (64, 1024)
# Encoder c vector shape: (batch size, units) (64, 1024)

# %% [markdown]
# # Decoder

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE, 
                  max_length_input, max_length_output, 'luong')

# %% [markdown]
# ## Test Decoder

# %%
# Test decoder stack
sample_x = tf.random.uniform((BATCH_SIZE, max_length_output))
decoder.attention_mechanism.setup_memory(sample_output)
initial_state = decoder.build_initial_state(BATCH_SIZE, [sample_h, sample_c], tf.float32)

sample_decoder_outputs = decoder(sample_x, initial_state)

print("Decoder Outputs Shape: ", sample_decoder_outputs.rnn_output.shape)
# Out:
# Decoder Outputs Shape:  (64, 48, 36)

# %% [markdown]
# # Optimizer and Loss Function

# %%
optimizer = tf.keras.optimizers.Adam()

def loss_function(real, pred):
  # real shape = (BATCH_SIZE, max_length_output)
  # pred shape = (BATCH_SIZE, max_length_output, tar_vocab_size )
  cross_entropy = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
  loss = cross_entropy(y_true=real, y_pred=pred)
  mask = tf.logical_not(tf.math.equal(real,0))   #output 0 for y=0 else output 1
  mask = tf.cast(mask, dtype=loss.dtype)  
  loss = mask* loss
  loss = tf.reduce_mean(loss)
  return loss

# %% [markdown]
# # Checkpoints

# %%
checkpoint_dir = './data/training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %% [markdown]
# # One train_step operations

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_h, enc_c = encoder(inp, enc_hidden)


    dec_input = targ[ : , :-1 ] # Ignore <end> token
    real = targ[ : , 1: ]         # ignore <start> token

    # Set the AttentionMechanism object with encoder_outputs
    decoder.attention_mechanism.setup_memory(enc_output)

    # Create AttentionWrapperState as initial_state for decoder
    decoder_initial_state = decoder.build_initial_state(BATCH_SIZE, [enc_h, enc_c], tf.float32)
    pred = decoder(dec_input, decoder_initial_state)
    logits = pred.rnn_output
    loss = loss_function(real, logits)

  variables = encoder.trainable_variables + decoder.trainable_variables
  gradients = tape.gradient(loss, variables)
  optimizer.apply_gradients(zip(gradients, variables))

  return loss

# %% [markdown]
# # Train

# %%
EPOCHS = 25

best_loss = 1
for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0
  # print(enc_hidden[0].shape, enc_hidden[1].shape)
  for (batch, (inp, targ)) in enumerate(train_dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))

  loss = total_loss / steps_per_epoch
  # save checkpoints with best loss
  if loss < best_loss:
    best_loss = loss
    print('Saving checkpoint for epoch {} Loss {:.4f}'.format(epoch + 1, total_loss / steps_per_epoch))
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 0.6585
# Epoch 1 Batch 100 Loss 0.4614
# Epoch 1 Batch 200 Loss 0.2636
# Epoch 1 Batch 300 Loss 0.1927
# Epoch 1 Batch 400 Loss 0.1635
# Epoch 1 Batch 500 Loss 0.1268
# Epoch 1 Batch 600 Loss 0.1506
# Epoch 1 Batch 700 Loss 0.1183
# Epoch 1 Batch 800 Loss 0.1279
# Epoch 1 Batch 900 Loss 0.0877
# Epoch 1 Batch 1000 Loss 0.1213
# Epoch 1 Batch 1100 Loss 0.1009
# Epoch 1 Batch 1200 Loss 0.0971
# Epoch 1 Batch 1300 Loss 0.1098
# Epoch 1 Batch 1400 Loss 0.0898
# Saving checkpoint for epoch 1 Loss 0.1385
# Epoch 1 Loss 0.1385
# Time taken for 1 epoch 227.73123383522034 sec
#
# Epoch 2 Batch 0 Loss 0.0962
# Epoch 2 Batch 100 Loss 0.0923
# Epoch 2 Batch 200 Loss 0.0889
# Epoch 2 Batch 300 Loss 0.0975
# Epoch 2 Batch 400 Loss 0.1080
# Epoch 2 Batch 500 Loss 0.0906
# Epoch 2 Batch 600 Loss 0.0884
# Epoch 2 Batch 700 Loss 0.0850
# Epoch 2 Batch 800 Loss 0.1165
# Epoch 2 Batch 900 Loss 0.1037
# Epoch 2 Batch 1000 Loss 0.0831
# Epoch 2 Batch 1100 Loss 0.0702
# Epoch 2 Batch 1200 Loss 0.0818
# Epoch 2 Batch 1300 Loss 0.0765
# Epoch 2 Batch 1400 Loss 0.1210
# Saving checkpoint for epoch 2 Loss 0.0768
# Epoch 2 Loss 0.0768
# Time taken for 1 epoch 216.80077624320984 sec
#
# Epoch 3 Batch 0 Loss 0.0927
# Epoch 3 Batch 100 Loss 0.0828
# Epoch 3 Batch 200 Loss 0.0783
# Epoch 3 Batch 300 Loss 0.1083
# Epoch 3 Batch 400 Loss 0.0958
# Epoch 3 Batch 500 Loss 0.0878
# Epoch 3 Batch 600 Loss 0.1080
# Epoch 3 Batch 700 Loss 0.1033
# Epoch 3 Batch 800 Loss 0.0946
# Epoch 3 Batch 900 Loss 0.0837
# Epoch 3 Batch 1000 Loss 0.0843
# Epoch 3 Batch 1100 Loss 0.0875
# Epoch 3 Batch 1200 Loss 0.0908
# Epoch 3 Batch 1300 Loss 0.1002
# Epoch 3 Batch 1400 Loss 0.0792
# Saving checkpoint for epoch 3 Loss 0.0694
# Epoch 3 Loss 0.0694
# Time taken for 1 epoch 216.83542776107788 sec
#
# Epoch 4 Batch 0 Loss 0.1024
# Epoch 4 Batch 100 Loss 0.0861
# Epoch 4 Batch 200 Loss 0.0865
# Epoch 4 Batch 300 Loss 0.0876
# Epoch 4 Batch 400 Loss 0.0810
# Epoch 4 Batch 500 Loss 0.0975
# Epoch 4 Batch 600 Loss 0.0662
# Epoch 4 Batch 700 Loss 0.0791
# Epoch 4 Batch 800 Loss 0.0781
# Epoch 4 Batch 900 Loss 0.0977
# Epoch 4 Batch 1000 Loss 0.0826
# Epoch 4 Batch 1100 Loss 0.0771
# Epoch 4 Batch 1200 Loss 0.0843
# Epoch 4 Batch 1300 Loss 0.0915
# Epoch 4 Batch 1400 Loss 0.0861
# Saving checkpoint for epoch 4 Loss 0.0648
# Epoch 4 Loss 0.0648
# Time taken for 1 epoch 216.79546356201172 sec
#
# Epoch 5 Batch 0 Loss 0.0823
# Epoch 5 Batch 100 Loss 0.0765
# Epoch 5 Batch 200 Loss 0.0720
# Epoch 5 Batch 300 Loss 0.0765
# Epoch 5 Batch 400 Loss 0.0794
# Epoch 5 Batch 500 Loss 0.0738
# Epoch 5 Batch 600 Loss 0.0808
# Epoch 5 Batch 700 Loss 0.0675
# Epoch 5 Batch 800 Loss 0.0609
# Epoch 5 Batch 900 Loss 0.0823
# Epoch 5 Batch 1000 Loss 0.0677
# Epoch 5 Batch 1100 Loss 0.0746
# Epoch 5 Batch 1200 Loss 0.0660
# Epoch 5 Batch 1300 Loss 0.0628
# Epoch 5 Batch 1400 Loss 0.0579
# Saving checkpoint for epoch 5 Loss 0.0617
# Epoch 5 Loss 0.0617
# Time taken for 1 epoch 217.07507514953613 sec
#
# Epoch 6 Batch 0 Loss 0.0833
# Epoch 6 Batch 100 Loss 0.0590
# Epoch 6 Batch 200 Loss 0.0667
# Epoch 6 Batch 300 Loss 0.0700
# Epoch 6 Batch 400 Loss 0.0731
# Epoch 6 Batch 500 Loss 0.0769
# Epoch 6 Batch 600 Loss 0.0617
# Epoch 6 Batch 700 Loss 0.0590
# Epoch 6 Batch 800 Loss 0.0817
# Epoch 6 Batch 900 Loss 0.0627
# Epoch 6 Batch 1000 Loss 0.0811
# Epoch 6 Batch 1100 Loss 0.0730
# Epoch 6 Batch 1200 Loss 0.1019
# Epoch 6 Batch 1300 Loss 0.0853
# Epoch 6 Batch 1400 Loss 0.0747
# Saving checkpoint for epoch 6 Loss 0.0588
# Epoch 6 Loss 0.0588
# Time taken for 1 epoch 216.74033045768738 sec
#
# Epoch 7 Batch 0 Loss 0.0666
# Epoch 7 Batch 100 Loss 0.0690
# Epoch 7 Batch 200 Loss 0.0733
# Epoch 7 Batch 300 Loss 0.0878
# Epoch 7 Batch 400 Loss 0.0679
# Epoch 7 Batch 500 Loss 0.0801
# Epoch 7 Batch 600 Loss 0.0674
# Epoch 7 Batch 700 Loss 0.0740
# Epoch 7 Batch 800 Loss 0.0597
# Epoch 7 Batch 900 Loss 0.0651
# Epoch 7 Batch 1000 Loss 0.0690
# Epoch 7 Batch 1100 Loss 0.0680
# Epoch 7 Batch 1200 Loss 0.0604
# Epoch 7 Batch 1300 Loss 0.0780
# Epoch 7 Batch 1400 Loss 0.0726
# Saving checkpoint for epoch 7 Loss 0.0563
# Epoch 7 Loss 0.0563
# Time taken for 1 epoch 216.64750814437866 sec
#
# Epoch 8 Batch 0 Loss 0.0802
# Epoch 8 Batch 100 Loss 0.0542
# Epoch 8 Batch 200 Loss 0.0614
# Epoch 8 Batch 300 Loss 0.0630
# Epoch 8 Batch 400 Loss 0.0639
# Epoch 8 Batch 500 Loss 0.0462
# Epoch 8 Batch 600 Loss 0.0781
# Epoch 8 Batch 700 Loss 0.0811
# Epoch 8 Batch 800 Loss 0.0770
# Epoch 8 Batch 900 Loss 0.0603
# Epoch 8 Batch 1000 Loss 0.0748
# Epoch 8 Batch 1100 Loss 0.0605
# Epoch 8 Batch 1200 Loss 0.0634
# Epoch 8 Batch 1300 Loss 0.0541
# Epoch 8 Batch 1400 Loss 0.0638
# Saving checkpoint for epoch 8 Loss 0.0541
# Epoch 8 Loss 0.0541
# Time taken for 1 epoch 218.04501461982727 sec
#
# Epoch 9 Batch 0 Loss 0.0575
# Epoch 9 Batch 100 Loss 0.0633
# Epoch 9 Batch 200 Loss 0.0788
# Epoch 9 Batch 300 Loss 0.0720
# Epoch 9 Batch 400 Loss 0.0616
# Epoch 9 Batch 500 Loss 0.0662
# Epoch 9 Batch 600 Loss 0.0694
# Epoch 9 Batch 700 Loss 0.0693
# Epoch 9 Batch 800 Loss 0.0665
# Epoch 9 Batch 900 Loss 0.0632
# Epoch 9 Batch 1000 Loss 0.0662
# Epoch 9 Batch 1100 Loss 0.0625
# Epoch 9 Batch 1200 Loss 0.0581
# Epoch 9 Batch 1300 Loss 0.0810
# Epoch 9 Batch 1400 Loss 0.0747
# Saving checkpoint for epoch 9 Loss 0.0523
# Epoch 9 Loss 0.0523
# Time taken for 1 epoch 216.78281354904175 sec
#
# Epoch 10 Batch 0 Loss 0.0683
# Epoch 10 Batch 100 Loss 0.0601
# Epoch 10 Batch 200 Loss 0.0519
# Epoch 10 Batch 300 Loss 0.0665
# Epoch 10 Batch 400 Loss 0.0619
# Epoch 10 Batch 500 Loss 0.0617
# Epoch 10 Batch 600 Loss 0.0694
# Epoch 10 Batch 700 Loss 0.0573
# Epoch 10 Batch 800 Loss 0.0771
# Epoch 10 Batch 900 Loss 0.0571
# Epoch 10 Batch 1000 Loss 0.0617
# Epoch 10 Batch 1100 Loss 0.0525
# Epoch 10 Batch 1200 Loss 0.0695
# Epoch 10 Batch 1300 Loss 0.0739
# Epoch 10 Batch 1400 Loss 0.0682
# Saving checkpoint for epoch 10 Loss 0.0503
# Epoch 10 Loss 0.0503
# Time taken for 1 epoch 216.3451669216156 sec
#
# Epoch 11 Batch 0 Loss 0.0663
# Epoch 11 Batch 100 Loss 0.0636
# Epoch 11 Batch 200 Loss 0.0496
# Epoch 11 Batch 300 Loss 0.0575
# Epoch 11 Batch 400 Loss 0.0722
# Epoch 11 Batch 500 Loss 0.0543
# Epoch 11 Batch 600 Loss 0.0488
# Epoch 11 Batch 700 Loss 0.0607
# Epoch 11 Batch 800 Loss 0.0601
# Epoch 11 Batch 900 Loss 0.0694
# Epoch 11 Batch 1000 Loss 0.0587
# Epoch 11 Batch 1100 Loss 0.0662
# Epoch 11 Batch 1200 Loss 0.0668
# Epoch 11 Batch 1300 Loss 0.0500
# Epoch 11 Batch 1400 Loss 0.0546
# Saving checkpoint for epoch 11 Loss 0.0487
# Epoch 11 Loss 0.0487
# Time taken for 1 epoch 217.07855606079102 sec
#
# Epoch 12 Batch 0 Loss 0.0537
# Epoch 12 Batch 100 Loss 0.0632
# Epoch 12 Batch 200 Loss 0.0628
# Epoch 12 Batch 300 Loss 0.0570
# Epoch 12 Batch 400 Loss 0.0841
# Epoch 12 Batch 500 Loss 0.0543
# Epoch 12 Batch 600 Loss 0.0562
# Epoch 12 Batch 700 Loss 0.0774
# Epoch 12 Batch 800 Loss 0.0532
# Epoch 12 Batch 900 Loss 0.0707
# Epoch 12 Batch 1000 Loss 0.0577
# Epoch 12 Batch 1100 Loss 0.0536
# Epoch 12 Batch 1200 Loss 0.0787
# Epoch 12 Batch 1300 Loss 0.0527
# Epoch 12 Batch 1400 Loss 0.0579
# Saving checkpoint for epoch 12 Loss 0.0476
# Epoch 12 Loss 0.0476
# Time taken for 1 epoch 217.12636995315552 sec
#
# Epoch 13 Batch 0 Loss 0.0493
# Epoch 13 Batch 100 Loss 0.0514
# Epoch 13 Batch 200 Loss 0.0502
# Epoch 13 Batch 300 Loss 0.0595
# Epoch 13 Batch 400 Loss 0.0425
# Epoch 13 Batch 500 Loss 0.0526
# Epoch 13 Batch 600 Loss 0.0570
# Epoch 13 Batch 700 Loss 0.0632
# Epoch 13 Batch 800 Loss 0.0570
# Epoch 13 Batch 900 Loss 0.0651
# Epoch 13 Batch 1000 Loss 0.0578
# Epoch 13 Batch 1100 Loss 0.0622
# Epoch 13 Batch 1200 Loss 0.0602
# Epoch 13 Batch 1300 Loss 0.0454
# Epoch 13 Batch 1400 Loss 0.0697
# Saving checkpoint for epoch 13 Loss 0.0470
# Epoch 13 Loss 0.0470
# Time taken for 1 epoch 217.09414339065552 sec
#
# Epoch 14 Batch 0 Loss 0.0543
# Epoch 14 Batch 100 Loss 0.0639
# Epoch 14 Batch 200 Loss 0.0450
# Epoch 14 Batch 300 Loss 0.0489
# Epoch 14 Batch 400 Loss 0.0535
# Epoch 14 Batch 500 Loss 0.0544
# Epoch 14 Batch 600 Loss 0.0651
# Epoch 14 Batch 700 Loss 0.0388
# Epoch 14 Batch 800 Loss 0.0462
# Epoch 14 Batch 900 Loss 0.0499
# Epoch 14 Batch 1000 Loss 0.0808
# Epoch 14 Batch 1100 Loss 0.0550
# Epoch 14 Batch 1200 Loss 0.0624
# Epoch 14 Batch 1300 Loss 0.0546
# Epoch 14 Batch 1400 Loss 0.0538
# Saving checkpoint for epoch 14 Loss 0.0458
# Epoch 14 Loss 0.0458
# Time taken for 1 epoch 217.36542129516602 sec
#
# Epoch 15 Batch 0 Loss 0.0384
# Epoch 15 Batch 100 Loss 0.0514
# Epoch 15 Batch 200 Loss 0.0449
# Epoch 15 Batch 300 Loss 0.0537
# Epoch 15 Batch 400 Loss 0.0657
# Epoch 15 Batch 500 Loss 0.0722
# Epoch 15 Batch 600 Loss 0.0537
# Epoch 15 Batch 700 Loss 0.0598
# Epoch 15 Batch 800 Loss 0.0538
# Epoch 15 Batch 900 Loss 0.0421
# Epoch 15 Batch 1000 Loss 0.0498
# Epoch 15 Batch 1100 Loss 0.0572
# Epoch 15 Batch 1200 Loss 0.0591
# Epoch 15 Batch 1300 Loss 0.0616
# Epoch 15 Batch 1400 Loss 0.0596
# Saving checkpoint for epoch 15 Loss 0.0441
# Epoch 15 Loss 0.0441
# Time taken for 1 epoch 217.1265778541565 sec
#
# Epoch 16 Batch 0 Loss 0.0526
# Epoch 16 Batch 100 Loss 0.0616
# Epoch 16 Batch 200 Loss 0.0544
# Epoch 16 Batch 300 Loss 0.0437
# Epoch 16 Batch 400 Loss 0.0656
# Epoch 16 Batch 500 Loss 0.0777
# Epoch 16 Batch 600 Loss 0.0665
# Epoch 16 Batch 700 Loss 0.0735
# Epoch 16 Batch 800 Loss 0.1104
# Epoch 16 Batch 900 Loss 0.0748
# Epoch 16 Batch 1000 Loss 0.0486
# Epoch 16 Batch 1100 Loss 0.0609
# Epoch 16 Batch 1200 Loss 0.0671
# Epoch 16 Batch 1300 Loss 0.0710
# Epoch 16 Batch 1400 Loss 0.0707
# Epoch 16 Loss 0.0504
# Time taken for 1 epoch 216.44691610336304 sec
#
# Epoch 17 Batch 0 Loss 0.0528
# Epoch 17 Batch 100 Loss 0.0580
# Epoch 17 Batch 200 Loss 0.0646
# Epoch 17 Batch 300 Loss 0.0742
# Epoch 17 Batch 400 Loss 0.0417
# Epoch 17 Batch 500 Loss 0.0483
# Epoch 17 Batch 600 Loss 0.0465
# Epoch 17 Batch 700 Loss 0.0576
# Epoch 17 Batch 800 Loss 0.0570
# Epoch 17 Batch 900 Loss 0.0446
# Epoch 17 Batch 1000 Loss 0.0492
# Epoch 17 Batch 1100 Loss 0.0481
# Epoch 17 Batch 1200 Loss 0.0570
# Epoch 17 Batch 1300 Loss 0.0502
# Epoch 17 Batch 1400 Loss 0.0429
# Saving checkpoint for epoch 17 Loss 0.0439
# Epoch 17 Loss 0.0439
# Time taken for 1 epoch 216.74948000907898 sec
#
# Epoch 18 Batch 0 Loss 0.0583
# Epoch 18 Batch 100 Loss 0.0391
# Epoch 18 Batch 200 Loss 0.0581
# Epoch 18 Batch 300 Loss 0.0433
# Epoch 18 Batch 400 Loss 0.0490
# Epoch 18 Batch 500 Loss 0.0792
# Epoch 18 Batch 600 Loss 0.0691
# Epoch 18 Batch 700 Loss 0.0917
# Epoch 18 Batch 800 Loss 0.0660
# Epoch 18 Batch 900 Loss 0.0601
# Epoch 18 Batch 1000 Loss 0.0536
# Epoch 18 Batch 1100 Loss 0.0535
# Epoch 18 Batch 1200 Loss 0.0547
# Epoch 18 Batch 1300 Loss 0.0610
# Epoch 18 Batch 1400 Loss 0.0636
# Epoch 18 Loss 0.0478
# Time taken for 1 epoch 216.33429789543152 sec
#
# Epoch 19 Batch 0 Loss 0.0566
# Epoch 19 Batch 100 Loss 0.0536
# Epoch 19 Batch 200 Loss 0.0735
# Epoch 19 Batch 300 Loss 11.8572
# Epoch 19 Batch 400 Loss 0.6993
# Epoch 19 Batch 500 Loss 0.6136
# Epoch 19 Batch 600 Loss 0.5357
# Epoch 19 Batch 700 Loss 0.5451
# Epoch 19 Batch 800 Loss 0.4911
# Epoch 19 Batch 900 Loss 0.4822
# Epoch 19 Batch 1000 Loss 0.4862
# Epoch 19 Batch 1100 Loss 0.5717
# Epoch 19 Batch 1200 Loss 0.5426
# Epoch 19 Batch 1300 Loss 0.4616
# Epoch 19 Batch 1400 Loss 0.4466
# Epoch 19 Loss 0.7224
# Time taken for 1 epoch 215.88376593589783 sec
#
# Epoch 20 Batch 0 Loss 0.5060
# Epoch 20 Batch 100 Loss 0.4890
# Epoch 20 Batch 200 Loss 0.4846
# Epoch 20 Batch 300 Loss 0.4650
# Epoch 20 Batch 400 Loss 0.3901
# Epoch 20 Batch 500 Loss 0.5108
# Epoch 20 Batch 600 Loss 0.4745
# Epoch 20 Batch 700 Loss 0.4956
# Epoch 20 Batch 800 Loss 0.4519
# Epoch 20 Batch 900 Loss 0.4320
# Epoch 20 Batch 1000 Loss 0.4283
# Epoch 20 Batch 1100 Loss 0.4329
# Epoch 20 Batch 1200 Loss 0.4607
# Epoch 20 Batch 1300 Loss 0.4068
# Epoch 20 Batch 1400 Loss 0.4447
# Epoch 20 Loss 0.3752
# Time taken for 1 epoch 216.2054944038391 sec
#
# Epoch 21 Batch 0 Loss 0.4808
# Epoch 21 Batch 100 Loss 0.4414
# Epoch 21 Batch 200 Loss 0.4532
# Epoch 21 Batch 300 Loss 0.4620
# Epoch 21 Batch 400 Loss 0.4305
# Epoch 21 Batch 500 Loss 0.4165
# Epoch 21 Batch 600 Loss 0.4444
# Epoch 21 Batch 700 Loss 0.4106
# Epoch 21 Batch 800 Loss 0.4192
# Epoch 21 Batch 900 Loss 0.4190
# Epoch 21 Batch 1000 Loss 0.4793
# Epoch 21 Batch 1100 Loss 0.4304
# Epoch 21 Batch 1200 Loss 0.3996
# Epoch 21 Batch 1300 Loss 0.4035
# Epoch 21 Batch 1400 Loss 0.3630
# Epoch 21 Loss 0.3465
# Time taken for 1 epoch 216.23831582069397 sec
#
# Epoch 22 Batch 0 Loss 0.4185
# Epoch 22 Batch 100 Loss 0.4254
# Epoch 22 Batch 200 Loss 0.3933
# Epoch 22 Batch 300 Loss 0.4342
# Epoch 22 Batch 400 Loss 0.4231
# Epoch 22 Batch 500 Loss 0.4066
# Epoch 22 Batch 600 Loss 0.3613
# Epoch 22 Batch 700 Loss 0.3751
# Epoch 22 Batch 800 Loss 0.3776
# Epoch 22 Batch 900 Loss 0.4040
# Epoch 22 Batch 1000 Loss 0.3930
# Epoch 22 Batch 1100 Loss 0.3928
# Epoch 22 Batch 1200 Loss 0.4035
# Epoch 22 Batch 1300 Loss 0.3902
# Epoch 22 Batch 1400 Loss 0.3717
# Epoch 22 Loss 0.3133
# Time taken for 1 epoch 216.46002674102783 sec
#
# Epoch 23 Batch 0 Loss 0.3767
# Epoch 23 Batch 100 Loss 0.3706
# Epoch 23 Batch 200 Loss 0.3244
# Epoch 23 Batch 300 Loss 0.3935
# Epoch 23 Batch 400 Loss 0.3544
# Epoch 23 Batch 500 Loss 0.3494
# Epoch 23 Batch 600 Loss 0.3665
# Epoch 23 Batch 700 Loss 0.3784
# Epoch 23 Batch 800 Loss 0.3069
# Epoch 23 Batch 900 Loss 0.3602
# Epoch 23 Batch 1000 Loss 0.3564
# Epoch 23 Batch 1100 Loss 0.3449
# Epoch 23 Batch 1200 Loss 0.3171
# Epoch 23 Batch 1300 Loss 0.3045
# Epoch 23 Batch 1400 Loss 0.3028
# Epoch 23 Loss 0.2776
# Time taken for 1 epoch 216.62765049934387 sec
#
# Epoch 24 Batch 0 Loss 0.3092
# Epoch 24 Batch 100 Loss 0.3085
# Epoch 24 Batch 200 Loss 0.3036
# Epoch 24 Batch 300 Loss 0.3162
# Epoch 24 Batch 400 Loss 0.3505
# Epoch 24 Batch 500 Loss 0.3449
# Epoch 24 Batch 600 Loss 0.2938
# Epoch 24 Batch 700 Loss 0.2867
# Epoch 24 Batch 800 Loss 0.2960
# Epoch 24 Batch 900 Loss 0.3104
# Epoch 24 Batch 1000 Loss 0.2761
# Epoch 24 Batch 1100 Loss 0.3364
# Epoch 24 Batch 1200 Loss 0.3030
# Epoch 24 Batch 1300 Loss 0.3251
# Epoch 24 Batch 1400 Loss 0.2712
# Epoch 24 Loss 0.2398
# Time taken for 1 epoch 216.3007092475891 sec
#
# Epoch 25 Batch 0 Loss 0.2838
# Epoch 25 Batch 100 Loss 0.2892
# Epoch 25 Batch 200 Loss 0.2655
# Epoch 25 Batch 300 Loss 0.2574
# Epoch 25 Batch 400 Loss 0.3017
# Epoch 25 Batch 500 Loss 0.2642
# Epoch 25 Batch 600 Loss 0.2894
# Epoch 25 Batch 700 Loss 0.2473
# Epoch 25 Batch 800 Loss 0.2753
# Epoch 25 Batch 900 Loss 0.2685
# Epoch 25 Batch 1000 Loss 0.2482
# Epoch 25 Batch 1100 Loss 0.2630
# Epoch 25 Batch 1200 Loss 0.2742
# Epoch 25 Batch 1300 Loss 0.2233
# Epoch 25 Batch 1400 Loss 0.2545
# Epoch 25 Loss 0.2102
# Time taken for 1 epoch 216.30212783813477 sec
#
# Epoch 26 Batch 0 Loss 0.2228
# Epoch 26 Batch 100 Loss 0.2102
# Epoch 26 Batch 200 Loss 0.2431
# Epoch 26 Batch 300 Loss 0.2197
# Epoch 26 Batch 400 Loss 0.2672
# Epoch 26 Batch 500 Loss 0.2002
# Epoch 26 Batch 600 Loss 0.2294
# Epoch 26 Batch 700 Loss 0.2751
# Epoch 26 Batch 800 Loss 0.2022
# Epoch 26 Batch 900 Loss 0.2441
# Epoch 26 Batch 1000 Loss 0.1885
# Epoch 26 Batch 1100 Loss 0.2022
# Epoch 26 Batch 1200 Loss 0.2192
# Epoch 26 Batch 1300 Loss 0.2143
# Epoch 26 Batch 1400 Loss 0.2423
# Epoch 26 Loss 0.1893
# Time taken for 1 epoch 216.07285499572754 sec
#
# Epoch 27 Batch 0 Loss 0.2653
# Epoch 27 Batch 100 Loss 0.2166
# Epoch 27 Batch 200 Loss 0.1851
# Epoch 27 Batch 300 Loss 0.2496
# Epoch 27 Batch 400 Loss 0.2235
# Epoch 27 Batch 500 Loss 0.1978
# Epoch 27 Batch 600 Loss 0.2155
# Epoch 27 Batch 700 Loss 0.2084
# Epoch 27 Batch 800 Loss 0.2083
# Epoch 27 Batch 900 Loss 0.2206
# Epoch 27 Batch 1000 Loss 0.2307
# Epoch 27 Batch 1100 Loss 0.2379
# Epoch 27 Batch 1200 Loss 0.2038
# Epoch 27 Batch 1300 Loss 0.2184
# Epoch 27 Batch 1400 Loss 0.1826
# Epoch 27 Loss 0.1743
# Time taken for 1 epoch 216.1950900554657 sec
#
# Epoch 28 Batch 0 Loss 0.1803
# Epoch 28 Batch 100 Loss 0.2537
# Epoch 28 Batch 200 Loss 0.1809
# Epoch 28 Batch 300 Loss 0.2095
# Epoch 28 Batch 400 Loss 0.1946
# Epoch 28 Batch 500 Loss 0.2316
# Epoch 28 Batch 600 Loss 1.4413
# Epoch 28 Batch 700 Loss 0.7572
# Epoch 28 Batch 800 Loss 0.6344
# Epoch 28 Batch 900 Loss 0.4926
# Epoch 28 Batch 1000 Loss 0.4719
# Epoch 28 Batch 1100 Loss 0.4787
# Epoch 28 Batch 1200 Loss 0.4777
# Epoch 28 Batch 1300 Loss 0.4844
# Epoch 28 Batch 1400 Loss 0.4022
# Epoch 28 Loss 0.5692
# Time taken for 1 epoch 215.6400966644287 sec
#
# Epoch 29 Batch 0 Loss 0.4469
# Epoch 29 Batch 100 Loss 0.4507
# Epoch 29 Batch 200 Loss 0.4484
# Epoch 29 Batch 300 Loss 0.5026
# Epoch 29 Batch 400 Loss 0.4396
# Epoch 29 Batch 500 Loss 0.4346
# Epoch 29 Batch 600 Loss 0.4787
# Epoch 29 Batch 700 Loss 0.4405
# Epoch 29 Batch 800 Loss 0.4562
# Epoch 29 Batch 900 Loss 0.4348
# Epoch 29 Batch 1000 Loss 0.4896
# Epoch 29 Batch 1100 Loss 0.4202
# Epoch 29 Batch 1200 Loss 0.3888
# Epoch 29 Batch 1300 Loss 0.4199
# Epoch 29 Batch 1400 Loss 0.3979
# Epoch 29 Loss 0.3485
# Time taken for 1 epoch 216.3094882965088 sec
#
# Epoch 30 Batch 0 Loss 0.4131
# Epoch 30 Batch 100 Loss 0.4732
# Epoch 30 Batch 200 Loss 0.4033
# Epoch 30 Batch 300 Loss 0.4151
# Epoch 30 Batch 400 Loss 0.4154
# Epoch 30 Batch 500 Loss 0.3961
# Epoch 30 Batch 600 Loss 0.3999
# Epoch 30 Batch 700 Loss 0.3937
# Epoch 30 Batch 800 Loss 0.3324
# Epoch 30 Batch 900 Loss 0.4075
# Epoch 30 Batch 1000 Loss 0.4259
# Epoch 30 Batch 1100 Loss 0.3506
# Epoch 30 Batch 1200 Loss 0.3829
# Epoch 30 Batch 1300 Loss 0.3448
# Epoch 30 Batch 1400 Loss 0.4259
# Epoch 30 Loss 0.3153
# Time taken for 1 epoch 215.9945285320282 sec
#
# Epoch 31 Batch 0 Loss 0.3476
# Epoch 31 Batch 100 Loss 0.3562
# Epoch 31 Batch 200 Loss 0.3866
# Epoch 31 Batch 300 Loss 0.3585
# Epoch 31 Batch 400 Loss 0.3627
# Epoch 31 Batch 500 Loss 0.3438
# Epoch 31 Batch 600 Loss 0.3527
# Epoch 31 Batch 700 Loss 0.3449
# Epoch 31 Batch 800 Loss 0.3534
# Epoch 31 Batch 900 Loss 0.4610
# Epoch 31 Batch 1000 Loss 0.3393
# Epoch 31 Batch 1100 Loss 0.2859
# Epoch 31 Batch 1200 Loss 0.3857
# Epoch 31 Batch 1300 Loss 0.3691
# Epoch 31 Batch 1400 Loss 0.3771
# Epoch 31 Loss 0.2828
# Time taken for 1 epoch 215.6908769607544 sec
#
# Epoch 32 Batch 0 Loss 0.3332
# Epoch 32 Batch 100 Loss 0.3151
# Epoch 32 Batch 200 Loss 0.2643
# Epoch 32 Batch 300 Loss 0.2924
# Epoch 32 Batch 400 Loss 0.3179
# Epoch 32 Batch 500 Loss 0.2769
# Epoch 32 Batch 600 Loss 0.3132
# Epoch 32 Batch 700 Loss 0.3929
# Epoch 32 Batch 800 Loss 0.2747
# Epoch 32 Batch 900 Loss 0.3141
# Epoch 32 Batch 1000 Loss 0.2998
# Epoch 32 Batch 1100 Loss 0.3390
# Epoch 32 Batch 1200 Loss 0.2763
# Epoch 32 Batch 1300 Loss 0.2712
# Epoch 32 Batch 1400 Loss 0.2177
# Epoch 32 Loss 0.2355
# Time taken for 1 epoch 215.89790678024292 sec
#
# Epoch 33 Batch 0 Loss 0.2708
# Epoch 33 Batch 100 Loss 0.2507
# Epoch 33 Batch 200 Loss 0.3246
# Epoch 33 Batch 300 Loss 0.2381
# Epoch 33 Batch 400 Loss 0.2005
# Epoch 33 Batch 500 Loss 0.1731
# Epoch 33 Batch 600 Loss 0.2504
# Epoch 33 Batch 700 Loss 0.2040
# Epoch 33 Batch 800 Loss 0.2481
# Epoch 33 Batch 900 Loss 0.2100
# Epoch 33 Batch 1000 Loss 0.2158
# Epoch 33 Batch 1100 Loss 0.2153
# Epoch 33 Batch 1200 Loss 0.1827
# Epoch 33 Batch 1300 Loss 0.2117
# Epoch 33 Batch 1400 Loss 0.2167
# Epoch 33 Loss 0.1814
# Time taken for 1 epoch 216.00964379310608 sec
#
# Epoch 34 Batch 0 Loss 0.2085
# Epoch 34 Batch 100 Loss 0.2462
# Epoch 34 Batch 200 Loss 0.1985
# Epoch 34 Batch 300 Loss 0.1953
# Epoch 34 Batch 400 Loss 0.1721
# Epoch 34 Batch 500 Loss 0.1682
# Epoch 34 Batch 600 Loss 0.2310
# Epoch 34 Batch 700 Loss 0.1411
# Epoch 34 Batch 800 Loss 0.1809
# Epoch 34 Batch 900 Loss 0.1937
# Epoch 34 Batch 1000 Loss 0.1523
# Epoch 34 Batch 1100 Loss 0.1518
# Epoch 34 Batch 1200 Loss 0.2194
# Epoch 34 Batch 1300 Loss 0.2112
# Epoch 34 Batch 1400 Loss 0.1760
# Epoch 34 Loss 0.1476
# Time taken for 1 epoch 215.72388172149658 sec
#
# Epoch 35 Batch 0 Loss 0.1753
# Epoch 35 Batch 100 Loss 0.2140
# Epoch 35 Batch 200 Loss 0.1580
# Epoch 35 Batch 300 Loss 0.1549
# Epoch 35 Batch 400 Loss 0.1323
# Epoch 35 Batch 500 Loss 0.2085
# Epoch 35 Batch 600 Loss 0.1392
# Epoch 35 Batch 700 Loss 0.1467
# Epoch 35 Batch 800 Loss 0.1595
# Epoch 35 Batch 900 Loss 0.1778
# Epoch 35 Batch 1000 Loss 0.1425
# Epoch 35 Batch 1100 Loss 0.1537
# Epoch 35 Batch 1200 Loss 0.1585
# Epoch 35 Batch 1300 Loss 0.1308
# Epoch 35 Batch 1400 Loss 0.1334
# Epoch 35 Loss 0.1294
# Time taken for 1 epoch 216.04845690727234 sec
#
# Epoch 36 Batch 0 Loss 0.1561
# Epoch 36 Batch 100 Loss 0.1444
# Epoch 36 Batch 200 Loss 0.1757
# Epoch 36 Batch 300 Loss 0.1500
# Epoch 36 Batch 400 Loss 0.1194
# Epoch 36 Batch 500 Loss 0.1568
# Epoch 36 Batch 600 Loss 0.1523
# Epoch 36 Batch 700 Loss 0.1396
# Epoch 36 Batch 800 Loss 0.1459
# Epoch 36 Batch 900 Loss 0.1442
# Epoch 36 Batch 1000 Loss 0.1270
# Epoch 36 Batch 1100 Loss 0.1508
# Epoch 36 Batch 1200 Loss 0.1186
# Epoch 36 Batch 1300 Loss 0.1338
# Epoch 36 Batch 1400 Loss 0.1452
# Epoch 36 Loss 0.1219
# Time taken for 1 epoch 216.12925267219543 sec
#
# Epoch 37 Batch 0 Loss 0.1259
# Epoch 37 Batch 100 Loss 0.2299
# Epoch 37 Batch 200 Loss 0.1511
# Epoch 37 Batch 300 Loss 0.1224
# Epoch 37 Batch 400 Loss 0.1803
# Epoch 37 Batch 500 Loss 0.1717
# Epoch 37 Batch 600 Loss 0.1432
# Epoch 37 Batch 700 Loss 0.1566
# Epoch 37 Batch 800 Loss 0.1403
# Epoch 37 Batch 900 Loss 0.1434
# Epoch 37 Batch 1000 Loss 0.1901
# Epoch 37 Batch 1100 Loss 0.1919
# Epoch 37 Batch 1200 Loss 0.1521
# Epoch 37 Batch 1300 Loss 0.1571
# Epoch 37 Batch 1400 Loss 0.1507
# Epoch 37 Loss 0.1267
# Time taken for 1 epoch 216.19201564788818 sec
#
# Epoch 38 Batch 0 Loss 0.1392
# Epoch 38 Batch 100 Loss 0.1169
# Epoch 38 Batch 200 Loss 0.1008
# Epoch 38 Batch 300 Loss 0.1345
# Epoch 38 Batch 400 Loss 0.1440
# Epoch 38 Batch 500 Loss 0.1479
# Epoch 38 Batch 600 Loss 0.1517
# Epoch 38 Batch 700 Loss 0.1463
# Epoch 38 Batch 800 Loss 0.1414
# Epoch 38 Batch 900 Loss 0.1952
# Epoch 38 Batch 1000 Loss 0.1482
# Epoch 38 Batch 1100 Loss 0.1233
# Epoch 38 Batch 1200 Loss 0.1409
# Epoch 38 Batch 1300 Loss 0.1630
# Epoch 38 Batch 1400 Loss 0.1235
# Epoch 38 Loss 0.1198
# Time taken for 1 epoch 216.24167585372925 sec
#
# Epoch 39 Batch 0 Loss 0.1349
# Epoch 39 Batch 100 Loss 0.1506
# Epoch 39 Batch 200 Loss 0.1386
# Epoch 39 Batch 300 Loss 0.1603
# Epoch 39 Batch 400 Loss 0.1628
# Epoch 39 Batch 500 Loss 0.2064
# Epoch 39 Batch 600 Loss 0.1422
# Epoch 39 Batch 700 Loss 0.1225
# Epoch 39 Batch 800 Loss 0.1427
# Epoch 39 Batch 900 Loss 0.1642
# Epoch 39 Batch 1000 Loss 0.1164
# Epoch 39 Batch 1100 Loss 0.1684
# Epoch 39 Batch 1200 Loss 0.1338
# Epoch 39 Batch 1300 Loss 0.1458
# Epoch 39 Batch 1400 Loss 0.1073
# Epoch 39 Loss 0.1196
# Time taken for 1 epoch 215.96283411979675 sec
#
# Epoch 40 Batch 0 Loss 0.1166
# Epoch 40 Batch 100 Loss 0.1482
# Epoch 40 Batch 200 Loss 0.1359
# Epoch 40 Batch 300 Loss 2.2848
# Epoch 40 Batch 400 Loss 0.7020
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-8c01f4b222cb> in <module>()
#       9   # print(enc_hidden[0].shape, enc_hidden[1].shape)
#      10   for (batch, (inp, targ)) in enumerate(train_dataset.take(steps_per_epoch)):
# ---> 11     batch_loss = train_step(inp, targ, enc_hidden)
#      12     total_loss += batch_loss
#      13
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
# -> 3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#    3133   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958       # No tape is watching; skip to running the function.
#    1959       return self._build_call_outputs(self._inference_function.call(
# -> 1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#    1962         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     601               inputs=args,
#     602               attrs=attrs,
# --> 603               ctx=ctx)
#     604         else:
#     605           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# KeyboardInterrupt:

# %%
encoder.embedding.variables
# Out:
# [<tf.Variable 'encoder/embedding/embeddings:0' shape=(166, 256) dtype=float32, numpy=
#  array([[-0.07065372, -0.04891422,  0.01282918, ...,  0.04568648,
#          -0.07823983, -0.07764788],
#         [-0.09147184,  0.19109847,  0.12537214, ..., -0.01790996,
#           0.00141883, -0.18570372],
#         [ 0.03353083,  0.1054965 , -0.06611574, ...,  0.01166355,
#          -0.11960571, -0.16839524],
#         ...,
#         [-0.19065775,  0.28302342,  0.07893948, ..., -0.1513373 ,
#           0.04492971,  0.12638961],
#         [ 0.09505298, -0.44047958,  0.02591725, ..., -0.02426921,
#          -0.421986  ,  0.23949109],
#         [-0.01180682,  0.13395208,  0.03590768, ...,  0.10349247,
#          -0.02466262,  0.2182667 ]], dtype=float32)>]

# %%
decoder.embedding.variables
# Out:
# [<tf.Variable 'decoder/embedding_1/embeddings:0' shape=(36, 256) dtype=float32, numpy=
#  array([[ 0.03724634, -0.02989709, -0.04813312, ..., -0.00780924,
#           0.00926129,  0.04338977],
#         [ 0.46307915, -0.22748752, -0.31411505, ...,  0.7708867 ,
#          -0.1213175 , -0.47693196],
#         [ 0.05063611,  0.08911494, -0.11557912, ...,  0.0591362 ,
#          -0.04259794, -0.08504502],
#         ...,
#         [-0.557036  , -0.32107395,  0.31832972, ...,  0.02268083,
#          -0.10818028, -0.12645367],
#         [ 0.45082635,  0.03947921, -0.22183114, ..., -0.04993758,
#           0.01296891, -0.06116186],
#         [-0.00486869, -0.15992434,  0.17243467, ...,  0.11373673,
#           0.10106619,  0.16622567]], dtype=float32)>]
